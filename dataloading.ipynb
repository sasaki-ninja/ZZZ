# %%
from typing import Tuple, Optional, List
import dask
import math
import xarray as xr
import numpy as np
import pandas as pd
import torch
import tqdm

from climate.data.era5 import ERA5DataLoader

# %%
dataloader = ERA5DataLoader()

# %%
sample_x, sample_y = dataloader.get_random_sample()
sample_x.shape, sample_y.shape
# Out:
# Fetching a sample live...
# Fetching done.
# (torch.Size([118, 13, 16, 3]), torch.Size([5, 13, 16, 3]))

# %%
data = xr.open_zarr("gs://gcp-public-data-arco-era5/ar/full_37-1h-0p25deg-chunk-1.zarr-v3", chunks=None)
data = data[["2m_temperature", "skin_temperature"]]
data = data.sel(time=slice("2023-01-02", "2023-01-02"))
data = data.chunk()
# Out:
# KeysView(<xarray.Dataset> Size: 199MB
# Dimensions:           (time: 24, latitude: 721, longitude: 1440)
# Coordinates:
#   * latitude          (latitude) float32 3kB 90.0 89.75 89.5 ... -89.75 -90.0
#   * longitude         (longitude) float32 6kB 0.0 0.25 0.5 ... 359.2 359.5 359.8
#   * time              (time) datetime64[ns] 192B 2023-01-02 ... 2023-01-02T23...
# Data variables:
#     2m_temperature    (time, latitude, longitude) float32 100MB dask.array<chunksize=(24, 721, 1440), meta=np.ndarray>
#     skin_temperature  (time, latitude, longitude) float32 100MB dask.array<chunksize=(24, 721, 1440), meta=np.ndarray>
# Attributes:
#     last_updated:      2025-01-12 11:54:41.741475
#     valid_time_start:  1940-01-01
#     valid_time_stop:   2024-10-31)

# %%
data["2m_temperature"]
# Out:
# <xarray.DataArray '2m_temperature' (time: 24, latitude: 721, longitude: 1440)> Size: 100MB
# dask.array<xarray-2m_temperature, shape=(24, 721, 1440), dtype=float32, chunksize=(24, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float32 3kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude  (longitude) float32 6kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#   * time       (time) datetime64[ns] 192B 2023-01-02 ... 2023-01-02T23:00:00
# Attributes:
#     long_name:   2 metre temperature
#     short_name:  t2m
#     units:       K
